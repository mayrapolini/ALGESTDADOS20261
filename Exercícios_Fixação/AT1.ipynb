# %% [markdown]
# <a href="https://colab.research.google.com/github/mayrapolini/ALGESTDADOS20261/blob/main/Exerc%C3%ADcios_Fixa%C3%A7%C3%A3o/AT1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Crie um programa que exiba na tela seu nome e sua idade.
nome="Mayra"
idade=24

print(nome,idade)
print(f"meu nome é {nome} e tenho {idade} anos")
# Out:
# Mayra 24
# meu nome é Mayra e tenho 24 anos

# %%
#Faça um programa que peça o nome do usuário e exiba uma mensagem de boas-vindas com o nome digitado.
nome="Mayra"

print(f"Boas vindas {nome}")
# Out:
# Boas vindas Mayra

# %%
#Desenvolva um programa que peça dois números ao usuário e mostre a soma entre eles.

numA= int(input("digite o primeiro número: "))
numB= int(input("digite o segundo número: "))
print(f"{numA} + {numB} = {numA + numB}")
# Out:
# digite o primeiro número: 2
# digite o segundo número: 6
# 2 + 6 = 8

# %%
#Crie um programa que peça um número inteiro e mostre seu antecessor e seu sucessor.
num= int(input("digite um numero "))
ant= num - 1
suc= num + 1

print(f"o antecessor é {ant}")
print(f"o sucessor é {suc}")
# Out:
# digite um numero 3
# o antecessor é 2
# o sucessor é 4

# %%
#Faça um programa que peça o ano de nascimento do usuário e calcule sua idade aproximada.

ano = int(input("Digite o ano em que nasceu "))
data = 2026
idade2= data - ano
print(f"Sua idade é {idade2}")
# Out:
# Digite o ano em que nasceu 2005
# Sua idade é 21

# %%
#Desenvolva um programa que peça duas notas e calcule a média entre elas.

notaA = float(input("digite a primeira nota: "))
notab = float(input("digite a segunda nota: "))

print(f"A média do aluno é: {(notaA+notab)/2}")
# Out:
# digite a primeira nota: 5.5
# digite a segunda nota: 5.5
# A média do aluno é: 5.5

# %%
temperatura = float(input("digite a temperatura"))
print(f"")
# Out:
#   File "/tmp/ipython-input-245/1312182302.py", line 2
#     print(f{temperatura*1,8+32})
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
