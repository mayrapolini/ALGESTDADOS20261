# %% [markdown]
# <a href="https://colab.research.google.com/github/mayrapolini/ALGESTDADOS20261/blob/main/Atividades_Avaliativas/MAYRA_POLINI_MARTINS_LISTA_AVALIATIVA_I.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 01 - Classificador de Três Números

num1 = int(input("Digite o 1º número: "))
num2 = int(input("Digite o 2º número: "))
num3 = int(input("Digite o 3º número: "))

if num1 >= num2 and num1 >= num3:
    maior = num1
elif num2 >= num1 and num2 >= num3:
    maior = num2
else:
    maior = num3

if num1 <= num2 and num1 <= num3:
    menor = num1
elif num2 <= num1 and num2 <= num3:
    menor = num2
else:
    menor = num3

meio = num1
if (num1 >= num2 and num1 <= num3) or (num1 <= num2 and num1 >= num3):
    meio = num1
elif (num2 >= num1 and num2 <= num3) or (num2 <= num1 and num2 >= num3):
    meio = num2
else:
    meio = num3

print(f"Maior: {maior}, meio: {meio}, menor: {menor}")

# %%
# 02 - Calculadora de Gorjeta

valor = float(input('Digite o valor da conta: '))
avaliacao = int(input('Digite a avaliação (1 a 5): '))

if valor >= 0 and 1 <= avaliacao <= 5:
    if avaliacao == 5:
        gorjeta = valor * 0.20
    elif avaliacao == 4:
        gorjeta = valor * 0.15
    elif avaliacao == 3:
        gorjeta = valor * 0.10
    else:
        gorjeta = 0

    total = valor + gorjeta

    print(f"Valor da conta: R${valor:.2f}\nGorjeta: R${gorjeta:.2f}\nTotal a pagar: R${total:.2f}")
else:
    print("Valores inválidos. Verifique se o valor é positivo e a avaliação está entre 1 e 5.")

# %%
# 03 - Verificador de Ano Bissexto

ano = int(input('Digite o ano desejado: '))

if ano > 0:
    if (ano % 400) == 0:
        resultado = "bissexto"
    else:
        if (ano % 100) == 0:
            resultado = "não-bissexto"
        else:
            if (ano % 4) == 0:
                resultado = "bissexto"
            else:
                resultado = "não-bissexto"
    print(f"O ano {ano} é {resultado}.")
else:
    print("Ano inválido. Digite um valor positivo.")

# %%
# 04 - Cálculo de Imposto de Renda Simplificado

salario = float(input('Digite o salario: '))

if salario >= 0:
    if salario <= 2259:
        aliquota = 0
        imposto = 0
    elif salario <= 2826:
        aliquota = 7.5
        imposto = salario * 0.075
    elif salario <= 3751:
        aliquota = 15
        imposto = salario * 0.15
    elif salario <= 4664:
        aliquota = 22.5
        imposto = salario * 0.225
    else:
        aliquota = 27.5
        imposto = salario * 0.275
    print(f'Salário bruto: R${salario:.2f}\nAlíquota aplicada: {aliquota}%\nValor do imposto: R${imposto:.2f}\nSalário líquido: R${salario-imposto:.2f}')
else:
    print('Valor digitado inválido')

# %%
#  05 - Placar de Futebol

timeA = int(input('Digite o número de gols do time A: '))
timeB = int(input('Digite o número de gols do time B: '))

if timeA >= 0 and timeB >= 0:
    if timeA > timeB and timeA - timeB > 3:
        print(f'Time A venceu por goleada. Diferença de gols: {timeA-timeB}')
    elif timeA > timeB:
        print(f'Time A venceu. Diferença de gols: {timeA-timeB}')
    elif timeB > timeA and timeB - timeA > 3:
        print(f'Time B venceu por goleada. Diferença de gols: {timeB-timeA}')
    elif timeB > timeA:
        print(f'Time B venceu. Diferença de gols: {timeB-timeA}')
    else:
        print('Houve empate entre o time A e o time B')
else:
    print('Número inválido')

# %%
# 06 - Validador de Data

dia = int(input('Digite o dia: '))
mes = int(input('Digite o mês: '))
ano = int(input('Digite o ano: '))

if ano > 0:
    if 1 <= mes <= 12:
        if (ano % 400) == 0:
            bissexto = True
        else:
            if (ano % 100) == 0:
                bissexto = False
            else:
                if (ano % 4) == 0:
                    bissexto = True
                else:
                    bissexto = False
        if mes == 2:
            if bissexto:
                if 1 <= dia <= 29:
                    print("Data válida")
                else:
                    print("Dia inválido para fevereiro em ano bissexto")
            else:
                if 1 <= dia <= 28:
                    print("Data válida")
                else:
                    print("Dia inválido para fevereiro em ano não bissexto")
        else:
            if mes == 4 or mes == 6 or mes == 9 or mes == 11:
                if 1 <= dia <= 30:
                    print("Data válida")
                else:
                    print("Mês com 30 dias. Dia inválido.")
            else:
                if 1 <= dia <= 31:
                    print("Data válida")
                else:
                    print("Mês com 31 dias. Dia inválido.")
    else:
        print("Mês inválido")
else:
    print("Ano inválido")

# %%
# 07 - Calculadora de Frete

peso = float(input('Digite o peso do pacote em kg: '))
codigo = int(input('Digite o código da região (1 = Sul/Sudeste, 2 = Centro-Oeste/Nordeste, 3 = Norte): '))

if peso > 0 and 1 <= codigo <= 3:
    if peso <= 1:
        frete = 15
    elif peso <= 5:
        frete = 25
    else:
        frete = 40
        if codigo == 2 or codigo == 3:
            frete = frete * 1.2
    print(f'Peso do pacote: {peso} kg\nRegião: {codigo}\nFrete total: R${frete:.2f}')
else:
    print('Dados inválidos')

# %%
# 08 - Simulador de Caixa Eletrônico

saldo = 1500
senha = '1234f'

saque = float(input("Digite o valor que deseja sacar: "))
senha_digitada = input('Digite a senha: ')

if saque > 0:
    if senha_digitada == senha:
        if saque <= saldo:
            saldo = saldo - saque
            print(f"Saque no valor de R${saque:.2f} realizado com sucesso.\nSaldo restante: R${saldo:.2f}")
        else:
            print('Saldo insuficiente')
    else:
        print('Senha incorreta')
else:
    print('Valor de saque inválido')

# %%
# 09 - Conversor de Temperatura Completo

temperatura = float(input('Digite a temperatura: '))
unidade = input('Digite a unidade de medida ("C" para Celsius, "F" para Fahrenheit ou "K" para Kelvin): ').upper()

match unidade:
    case "K":
        if temperatura >= 0:
            temp_celsius = temperatura - 273.15
            temp_fahrenheit = (temperatura - 273.15) * 1.8 + 32
            print(f"Temperatura em Kelvin: {temperatura}\nTemperatura em Celsius: {temp_celsius:.2f}°C\nTemperatura em Fahrenheit: {temp_fahrenheit:.2f}°F")
        else:
            print("Temperatura em Kelvin não pode ser negativa.")
    case "C":
        temp_kelvin = temperatura + 273.15
        temp_fahrenheit = (temperatura * 1.8) + 32
        print(f"Temperatura em Celsius: {temperatura}\nTemperatura em Kelvin: {temp_kelvin:.2f}K\nTemperatura em Fahrenheit: {temp_fahrenheit:.2f}°F")
    case "F":
        temp_celsius = (temperatura - 32) / 1.8
        temp_kelvin = temp_celsius + 273.15
        print(f"Temperatura em Fahrenheit: {temperatura}\nTemperatura em Celsius: {temp_celsius:.2f}°C\nTemperatura em Kelvin: {temp_kelvin:.2f}K")

    case _:
        print("Unidade inválida. Use C, F ou K.")

# %%
# 10 - Classificador de IMC com Risco

peso = float(input('Digite o peso (kg): '))
altura = float(input("Digite a altura (m): "))

if peso > 0 and 0.5 <= altura <= 2.5:
    imc = peso / (altura * altura)
    if imc < 18.5:
        classificacao = "Abaixo do peso"
        risco = "baixo"
    elif imc < 25:
        classificacao = "Normal"
        risco = "baixo"
    elif imc < 30:
        classificacao = "Sobrepeso"
        risco = "moderado"
    elif imc < 35:
        classificacao = "Obesidade Grau I"
        risco = "moderado"
    elif imc < 40:
        classificacao = "Obesidade Grau II"
        risco = "alto"
    else:
        classificacao = "Obesidade Grau III"
        risco = "alto"
    print(f"IMC: {imc:.2f}\nClassificação: {classificacao}\nRisco cardiovascular: {risco}")
else:
    print("Dados inválidos (peso ou altura fora do intervalo permitido)")

# %%
# 11 - Detector de Múltiplos

numero = int(input('Digite um numero: '))

if numero > 0:
    eh_multiplo_de_2 = False
    eh_multiplo_de_3 = False
    eh_multiplo_de_5 = False
    if numero % 2 == 0:
        eh_multiplo_de_2 = True
        print("É múltiplo de 2")
    if numero % 3 == 0:
        eh_multiplo_de_3 = True
        print("É múltiplo de 3")
    if numero % 5 == 0:
        eh_multiplo_de_5 = True
        print("É múltiplo de 5")
    if (eh_multiplo_de_2 and eh_multiplo_de_3 and eh_multiplo_de_5):
        print("É múltiplo de 2, 3 e 5 ao mesmo tempo")
else:
    print("Número inválido (deve ser positivo)")

# %%
# 12 - Calculadora de Desconto Progressivo

preco = float(input('Digite o preço do produto: '))
cupom = input("Informe o cupom de desconto (PROMO10, PROMO20, PROMO30 ou SEMCUPOM): ").upper()

desconto = 0

if preco > 0:

    match cupom:
        case "PROMO10":
            desconto = 10
        case "PROMO20":
            desconto = 20
        case "PROMO30":
            desconto = 30
        case _:
            desconto = 0

    # Regra do desconto máximo se preço < 50
    if preco < 50:
        if desconto > 10:
            desconto = 10

    desconto_valor = preco * (desconto / 100)
    preco_final = preco - desconto_valor

    print(f"Cupom usado: {cupom}\nDesconto: R${desconto_valor:.2f}\nPreço final: R${preco_final:.2f}")
else:
    print("Preço inválido")

# %%
# 13 - Avaliador de Triângulo Completo

lado1 = float(input("Digite o lado 1: "))
lado2 = float(input("Digite o lado 2: "))
lado3 = float(input("Digite o lado 3: "))

if lado1 > 0 and lado2 > 0 and lado3 > 0:
    if (lado1 < lado2 + lado3) and (lado2 < lado1 + lado3) and (lado3 < lado1 + lado2):
        if lado1 == lado2 and lado2 == lado3:
            print("Triângulo equilátero")
        elif lado1 == lado2 or lado1 == lado3 or lado2 == lado3:
            print("Triângulo isósceles")
        else:
            print("Triângulo escaleno")
    else:
        print("Os lados não formam um triângulo")
else:
    print("Todos os lados devem ser positivos")

# %%
# 14 - Calculadora de Notas com Conceito

nota1 = float(input('Digite a nota do aluno (0 a 10): '))
nota2 = float(input('Digite a nota do aluno (0 a 10): '))
nota3 = float(input('Digite a nota do aluno (0 a 10): '))
nota4 = float(input('Digite a nota do aluno (0 a 10): '))

if 0 <= nota1 <= 10 and 0 <= nota2 <= 10 and 0 <= nota3 <= 10 and 0 <= nota4 <= 10:
    media = (nota1 + nota2 + nota3 + nota4)/4
    if media >= 9:
        conceito = "A"
    elif media >= 7:
        conceito = "B"
    elif media >= 5:
        conceito = "C"
    elif media >= 3:
        conceito = "D"
    else:
        conceito = "E"
    if conceito == "A" or conceito == "B":
        status = "Aprovado"
    elif conceito == "C":
        status = "Recuperação"
    else:
        status = "Reprovado"
    print(f"Conceito: {conceito} - {status} - Média: {media:.2f}")
else:
    print("Valores informados inválidos")

# %%
# 15-Verificador de Acesso por Horário

hora = int(input("Digite a hora (0-23): "))
usuario = input("Digite o tipo de usuário (admin, operador, visitante): ").lower()

if hora < 0 or hora > 23:
    print("Hora inválida")
else:
    if 6 <= hora <= 11:
        turno = "manhã"
    elif 12 <= hora <= 17:
        turno = "tarde"
    elif 18 <= hora <= 23:
        turno = "noite"
    else:
        turno = "madrugada"

match usuario:
        case "admin":
                acesso = True
        case "operador":
            if turno == "manhã" or turno == "tarde":
                acesso = True
            else:
                acesso = False
        case "visitante":
            if turno == "tarde":
                acesso = True
            else:
                acesso = False
        case _:
            print("Usuário inválido")
            acesso = None

if acesso is not None:
        print(f"Acesso permitido. Turno atual: {turno}.")
else:
        print(f"Acesso negado. Turno atual: {turno}.")

# %%
# 16 - Simulador de Bomba de Combustível


gasolina = 6.75
etanol = 1.99
diesel = 6.20

tipo = input("Digite o combustível (gasolina, etanol, diesel): ").lower()
quantidade = float(input("Digite a quantidade de litros: "))


match tipo:
    case "gasolina":
        preco = gasolina
    case "etanol":
        preco = etanol
    case "diesel":
        preco = diesel
    case _:
        print("Combustível inválido!")
        preco = None

if preco is not None:
    if quantidade <= 0:
        print("Quantidade inválida!")
    else:
        subtotal = quantidade * preco
        if quantidade > 40:
            desconto = subtotal * 0.03
        else:
            desconto = 0
        total = subtotal - desconto

        print(f"Subtotal: R${(subtotal):.2f}\nDesconto: R${desconto:.2f}\nTotal: R${total:.2f}")

# %%
# 17 - Classificador de Velocidade

velocidade = float(input("Digite a velocidade (km/h): "))
via = input("Digite o tipo de via: ").lower()

match via:
    case "urbana":
        limite = 60
    case "rodovia":
        limite = 100
    case "autopista":
        limite = 120
    case _:
        print("Via inválida.")
        limite = None

if limite is not None:
    if velocidade < 0:
        print("Velocidade inválida!")
    else:
        if velocidade <= limite:
            situacao = "Dentro do limite"
        elif velocidade <= limite * 1.2:
            situacao = "Excesso leve"
        elif velocidade <= limite * 1.5:
            situacao = "Excesso moderado"
        else:
            situacao = "Excesso grave"

        print(f"Via: {via} - Limite: {limite} km/h - Velocidade: {velocidade} km/h - Situação: {situacao}")

# %%
# 18 - Calculadora de Parcelas com Juros

valor=float(input("Digite o valor da compra: "))
parcela=int(input("Digite o número de parcelas (1 a 12): "))

if valor >= 0 and 0 < parcela <= 12:

    if parcela == 1:
        juros = 0
    elif 2 <= parcela <= 3:
        juros = 0.05
    elif 4 <= parcela <= 6:
        juros = 0.1
    else:
        juros = 0.15

    valor_total = valor + (valor * juros)
    valor_parcela = valor_total / parcela

    if valor_parcela <= 20:
        parcela_min = valor_total // 20
        print(f"Parcela mínima não atingida. O número mínimo de parcelas é: {parcela_min}")

    else:
        print(f"Valor da compra: R${valor:.2f}\nQuantidade de parcelas: {parcela}\nJuros: {juros*100}%\nValor total da compra com juros: R${valor_total:.2f}\nValor da parcela com juros: R${valor_parcela:.2f}")

else:
    print("Valores inválidos!")

# %%
# 19 - Detector de Intervalo com Tolerância

alvo=float(input("Digite um valor alvo: "))
tolerancia=float(input("Digite a tolerância: "))
medido=float(input("Digite o valor medido: "))

if alvo >= 0 and tolerancia >= 0 and medido >= 0:
    limite_inferior = alvo - tolerancia
    limite_superior = alvo + tolerancia
    if medido < limite_inferior:
        print(f'Alvo: {alvo} - Desvio: {alvo-medido} - Classificação: Abaixo do limite')
    elif limite_inferior <= medido <= limite_superior :
        print(f'Alvo: {alvo} - Desvio: {alvo-medido} - Classificação: Dentro da faixa')
    else:
        print(f'Alvo: {alvo} - Desvio: {medido-alvo} - Classificação: Acima do limite')

# %%
# 20 - Simulador de Pedágio Inteligente

veiculo = input("Informe o tipo de veículo (moto, carro, caminhao ou onibus): ").lower()
tag = input("Possui tag de pagamento automático? S/N: ").upper()
hora = int(input("Digite o horário (0-23): "))

moto = 5.00
carro = 12.00
onibus = 25.00
caminhao = 40.00

match veiculo:
    case "moto":
        pedagio = moto
    case "carro":
        pedagio = carro
    case "caminhao":
        pedagio = caminhao
    case "onibus":
        pedagio = onibus
    case _:
        pedagio = 0

if tag == "S":
    desconto = pedagio * 0.10
else:
    desconto = 0

pedagio = pedagio - desconto


if (7 <= hora <= 9) or (17 <= hora <= 19):
    acrescimo = pedagio * 0.20
else:
    acrescimo = 0

pedagio_final = pedagio + acrescimo

print(f"Desconto tag: R${desconto:.2f}\nAcréscimo horário: R${acrescimo:.2f}\nTotal a pagar: R${pedagio_final:.2f}")

# %%
# 21 - Calculadora de Energia Elétrica

consumo = float(input("Digite o consumo mensal de energia em kWh: "))

if consumo >= 0:
    if 0 <= consumo <= 100:
        valor = consumo * 0.50
    elif 101 <= consumo <= 200:
        valor = consumo * 0.75
    elif 201 <= consumo <= 300:
        valor = consumo * 1.00
    else:
        valor = consumo * 1.50

    desconto = 0

    if consumo > 300:
        modo = input("Optou pelo modo econômico (s/n)? ").lower()
        if modo == "s":
            desconto = valor * 0.10

    valor_final = valor - desconto

    print(f"Consumo: {consumo} kWh\nValor sem desconto: R${valor:.2f}\nDesconto: R${desconto:.2f}\nValor final: R${valor_final:.2f}")
else:
    print("Valor inválido")

# %%
# 22 - Verificador de Intervalo Múltiplo

A = int(input('Digite um intervalo mínimo: '))
B = int(input('Digite um intervalo máximo: '))
N = int(input('Digite um número: '))
D = int(input('Digite um divisor (positivo e não nulo): '))


if A >= B:
    print('Intervalo inválido: A deve ser menor que B.')
elif D <= 0:
    print('Divisor inválido: deve ser positivo e não nulo.')
else:
    if A <= N <= B:
        if N % D == 0:
            print(f'O número {N} está dentro do intervalo [{A},{B}] e é divisível por {D}')
        else:
            print(f'O número {N} está dentro do intervalo [{A},{B}] e não é divisível por {D}')
    else:
        if N % D == 0:
            print(f'O número {N} está fora do intervalo [{A},{B}] e é divisível por {D}')
        else:
            print(f'O número {N} está fora do intervalo [{A},{B}] e não é divisível por {D}')

# %%
# 23 - Sistema de Pontuação de Jogo

jogador_1 = int(input('Digite a pontuação do 1º jogador: '))
jogador_2 = int(input('Digite a pontuação do 2º jogador: '))
jogador_3 = int(input('Digite a pontuação do 3º jogador: '))

if 0 <= jogador_1 <= 1000 and 0 <= jogador_2 <= 1000 and 0 <= jogador_3 <= 1000:
    if jogador_1 == jogador_2 == jogador_3:
        print('Todos os jogadores empataram com a mesma pontuação.')
    else:
        if jogador_1 >= jogador_2 and jogador_1 >= jogador_3:
            primeiro = jogador_1
            if jogador_2 >= jogador_3:
                segundo = jogador_2
                terceiro = jogador_3
            else:
                segundo = jogador_3
                terceiro = jogador_2
        elif jogador_2 >= jogador_1 and jogador_2 >= jogador_3:
            primeiro = jogador_2
            if jogador_1 >= jogador_3:
                segundo = jogador_1
                terceiro = jogador_3
            else:
                segundo = jogador_3
                terceiro = jogador_1
        else:
            primeiro = jogador_3
            if jogador_1 >= jogador_2:
                segundo = jogador_1
                terceiro = jogador_2
            else:
                segundo = jogador_2
                terceiro = jogador_1

        diferenca = primeiro - terceiro

        print(f'\nRANKING FINAL:\n1º lugar: {primeiro}\n2º lugar: {segundo}\n3º lugar: {terceiro}\nDiferença entre 1º e 3º: {diferenca}')
else:
    print('Pontuação inválida. Digite valores entre 0 e 1000.')

# %%
# 24 - Calculadora de Reajuste Salarial

salario = float(input("Digite o salario atual: "))
desempenho = int(input("Digite a avaliação de desempenho: "))

if salario >= 0 and 0 <= desempenho <= 100:
    if desempenho >= 90:
        reajuste = salario * 1.15
        percentual = 15
    elif desempenho >= 75:
        reajuste = salario * 1.10
        percentual = 10
    elif desempenho >= 60:
        reajuste = salario * 1.05
        percentual = 5
    else:
        reajuste = salario
        percentual = 0
    if reajuste > 15000:
        print(f'O salário atingiu o teto máximo de R$15.000,00 - Salário anterior: R${salario:.2f} - Percentual aplicado: {percentual}% - Reajuste: R${15000 - salario:.2f} - Novo salário: R$15000.00')
    else:
        print(f'Salário anterior: R${salario:.2f} -Percentual aplicado: {percentual}% - Reajuste: R${reajuste - salario:.2f} - Novo salário: R${reajuste:.2f}')
else:
    print('Valores inválidos.')

# %%
# 25 - Classificador de Triângulo com Ângulos

angulo1 = int(input('Digite o 1º angulo do triângulo em graus: '))
angulo2 = int(input('Digite o 2º angulo do triângulo em graus: '))
angulo3 = int(input('Digite o 3º angulo do triângulo em graus: '))

if angulo1 >= 0 and angulo2 >= 0 and angulo3 >= 0:
    if angulo1 + angulo2 + angulo3 != 180:
        print(f"Trinângulo inválido. Soma dos angulos = {angulo1+angulo2+angulo3}°")
    elif angulo1 < 90 and angulo2 < 90 and angulo3 < 90:
        print(f"Trinângulo acutângulo (todos os angulos < 90°)")
        if angulo1 == angulo2 == angulo3:
            print("Classificação quanto aos lados: Equilátero")
        elif angulo1 == angulo2 or angulo1 == angulo3 or angulo2 == angulo3:
            print("Classificação quanto aos lados: Isósceles")
        else:
            print("Classificação quanto aos lados: Escaleno")
    elif angulo1 == 90 or angulo2 == 90 or angulo3 == 90:
        print(f"Trinângulo retângulo (um angulo é = 90°)")
        if angulo1 == angulo2 == angulo3:
            print("Classificação quanto aos lados: Equilátero")
        elif angulo1 == angulo2 or angulo1 == angulo3 or angulo2 == angulo3:
            print("Classificação quanto aos lados:  Isósceles")
        else:
            print("Classificação quanto aos lados: Escaleno")
    else:
        print(f"Trinângulo obtusângulo (um angulo é > 90°)")
        if angulo1 == angulo2 == angulo3:
            print("Classificação quanto aos lados: Equilátero")
        elif angulo1 == angulo2 or angulo1 == angulo3 or angulo2 == angulo3:
            print("Classificação quanto aos lados: Isósceles")
        else:
            print("Classificação quanto aos lados: Escaleno")

# %%
# 26 - Calculadora de Combustível de Viagem

distancia = float(input('Digite a distância percorrida (km): '))
consumo = float(input('Digite o consumo do veículo (km/l): '))
preco = float(input('Digite o preço do litro de combustível (R$/l): '))

if distancia > 0 and consumo > 0 and preco > 0:
    litros = distancia/consumo
    if litros * preco > 500:
        print(f'Para o percurso de {distancia:.2f}km serão necessários {litros:.2f}l de combustível - Valor total: R${preco*litros:.2f}. Parada sugerida em {distancia/2:.2f}km para reabastecimento')
    else:
        print(f'Para o percurso de {distancia:.2f}km serão necessários {litros:.2f}l de combustível - Valor total: R${preco*litros:.2f}')
else:
    print('Valores inválidos. Digite apenas números positivos.')

# %%
# 27 - Verificador de Senha com Nível de Segurança

senha = input('Digite a senha: ')
confirmacao = input('Digite novamente a senha: ')

if senha != confirmacao:
    print('Senhas não conferem')
else:
    if 0 <= len(senha) < 6:
        nivel = 'Fraca'
    elif 6 <= len(senha) <= 9:
        nivel = 'Média'
    else:
        nivel = 'Forte'
    if senha.isdigit():
        if nivel == 'Forte':
            nivel = 'Média'
        elif nivel == 'Média':
            nivel = 'Fraca'
    print(nivel)

# %%
# 28 - Simulador de Reserva de Assento

assento = int(input('Digite o número do assento: '))
classe = input('Digite a  classe (economica, executiva ou primeira): ').lower()

if 1 <= assento <= 100:
    match classe:
        case "primeira":
            if assento <= 10:
                print('Número do assento e classe compatíveis. Valor: R$1.500,00. Deseja reservar?')
            else:
                print("O número do assento não é compatível com a classe.")
        case "executiva":
            if 11 <= assento <= 30:
                print('Número do assento e classe compatíveis. Valor: R$890,00. Deseja reservar?')
            else:
                print("O número do assento não é compatível com a classe.")
        case "economica":
            if 31 <= assento <= 100:
                print('Número do assento e classe compatíveis. Valor: R$350,00. Deseja reservar?')
            else:
                print("O número do assento não é compatível com a classe.")
        case _:
            print("Classe inválida.")
else:
    print("Número de assento inválido.")

# %%
# 29 - Simulador de Batalha por Tipos

atacante = input('Digite o tipo do atacante (fogo, agua, planta, eletrico, terra): ').lower()
defensor = input('Digite o tipo do defensor (fogo, agua, planta, eletrico, terra): ').lower()
poder = float(input('Digite o poder base do ataque: '))

match atacante:
    case 'fogo':
        if defensor == 'planta':
            dano_final = poder * 2
        elif defensor == 'agua':
            dano_final = poder * 0.5
        else:
            dano_final = poder
    case 'agua':
        if defensor == 'fogo':
            dano_final = poder * 2
        elif defensor == 'planta':
            dano_final = poder * 0.5
        else:
            dano_final = poder
    case 'planta':
        if defensor == 'agua':
            dano_final = poder * 2
        elif defensor == 'fogo':
            dano_final = poder * 0.5
        else:
            dano_final = poder
    case 'eletrico':
        if defensor == 'agua':
            dano_final = poder * 2
        elif defensor == 'terra':
            dano_final = poder * 0.5
        else:
            dano_final = poder
    case 'terra':
        if defensor == 'eletrico':
            dano_final = poder * 2
        elif defensor == 'agua':
            dano_final = poder * 0.5
        else:
            dano_final = poder
    case _:
        print('Tipo inválido.')

print(f'Dano final causado: {dano_final:.2f}')

# %%
# 30 - Sistema Completo de Reserva de Hotel

tipo = input('Digite o tipo de acomodação (standard, luxo, suite): ').lower()
diaria = int(input('Digite o número de diárias: '))
fidelidade = input('Possui cartão fidelidade(s/n)? ').lower()

standard = 280.00
suite = 450.00
luxo = 800.00

if diaria > 0:
    match tipo:
        case 'standard':
            diaria_base = standard * diaria
        case 'luxo':
            diaria_base = luxo * diaria
        case 'suite':
            diaria_base = suite * diaria
        case _:
            print('Tipo de acomodação inválido.')
    if 1 <= diaria <= 3:
        desconto_qtd = 0
    elif 4 <= diaria <= 7:
        desconto_qtd = diaria_base * 0.10
    else:
        desconto_qtd = diaria_base * 0.20

    subtotal = diaria_base - desconto_qtd

    if fidelidade == 's':
        desconto_fidelidade = subtotal * 0.05
    else:
        desconto_fidelidade = 0

    total_final = subtotal - desconto_fidelidade

    if total_final < 100:
        total_final = 100

    print(f'Resumo da reserva:\nTipo: {tipo}\nDiárias: {diaria}\nValor base: R${diaria_base:.2f}\nDesconto por quantidade: R${desconto_qtd:.2f}\nDesconto fidelidade: R${desconto_fidelidade:.2f}\nTotal final: R${total_final:.2f}')
else:
    print('Número de diárias inválido.')
