# %% [markdown]
# <a href="https://colab.research.google.com/github/mayrapolini/ALGESTDADOS20261/blob/main/TESTE/2026_semana1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("to fome")
# Out:
# to fome

# %%
print("quero almoçar")
# Out:
# quero almoçar
